# %%
import pennylane as qml
import numpy as np
from itertools import permutations
import matplotlib.pyplot as plt

# %%
n_comp = 1  # Num of compressed qubit, n_comp<n_inp
n_inp = 2  # Num of input qubits
anc = 1     # Ancilla
totqubit = n_inp+n_comp+anc

allwires = [i for i in range(totqubit)]

dev = qml.device('default.qubit', wires=totqubit)

def ctr_rot(paras,ctr=None,targ=None):
    if ctr is None or targ is None:
            raise ValueError(f"Need to assign wires as control and target.")
    if len(paras) != 3:
            raise ValueError(f"Three Parameters needed; got {len(paras)}.")
    qml.RZ(paras[0], wires=targ)
    qml.CNOT(wires=[ctr,targ])
    qml.RY(paras[1], wires=targ)
    qml.CNOT(wires=[ctr,targ])
    qml.RZ(paras[2], wires=targ)

@qml.qnode(dev)
def circuit(params,inp=None):
    if len(params) != 3*n_inp*(n_inp-1)+6*n_inp:
                raise ValueError(f"Parameters must be a {3*n_inp*(n_inp-1)+6*n_inp} vector; got length {len(params)}.")
    if len(inp) != 2**n_inp:
                raise ValueError(f"Input state-vector length wrong! Got length {len(inp)}")
                
    # Initialization
    qml.AmplitudeEmbedding(features=inp, wires=allwires[:n_inp],normalize=True)
    #qml.AmplitudeEmbedding(features=refs, wires=allwires[n_inp:n_inp+n_comp],normalize=True)
    
    # Prepare U
    paracnt = 0
    for i in range(n_inp):
        qml.RZ(params[paracnt], wires=i)
        qml.RY(params[paracnt+1], wires=i)
        qml.RZ(params[paracnt+2], wires=i)
        paracnt += 3
    
    perm = list(permutations(allwires[:n_inp], 2))
    for i in perm:
        ctr_rot(paras=[params[paracnt],params[paracnt+1],params[paracnt+2]],ctr=i[0],targ=i[1])
        paracnt += 3
    
    for i in range(n_inp):
        qml.RZ(params[paracnt], wires=i)
        qml.RY(params[paracnt+1], wires=i)
        qml.RZ(params[paracnt+2], wires=i)
        paracnt += 3
    
    # SWAP Test
    qml.Hadamard(wires=totqubit-1)
    for i in allwires[n_comp:n_inp]:
        qml.CSWAP(wires=[totqubit-1,i,i+n_comp])
    qml.Hadamard(wires=totqubit-1)
    
    return qml.expval(qml.PauliZ(totqubit-1))

def cost(params):
    C2 = 0
    for inp in inputs:
        res = circuit(params,inp) 
        C2 = C2 + res
    return 1-C2/len(inputs)

# %%
init_params = np.random.random(3*n_inp*(n_inp-1)+6*n_inp)

# %%
inputs = [[1,1,1,9],[2,1,2,1]]

#opt = qml.GradientDescentOptimizer(stepsize=0.05)
opt = qml.AdagradOptimizer(stepsize=0.1)
# set the number of steps
steps = 1000

params = init_params

for i in range(steps):
    # update the circuit parameters
    params = opt.step(cost, params)
    
    print("Cost after step {:5d}: {:8f}".format(i + 1, cost(params)))
print(f"Optimized params:{params}")
# Out:
# Cost after step     1: 0.543574
# Cost after step     2: 0.477166
# Cost after step     3: 0.410682
# Cost after step     4: 0.355655
# Cost after step     5: 0.317366
# Cost after step     6: 0.292933
# Cost after step     7: 0.277451
# Cost after step     8: 0.267453
# Cost after step     9: 0.260800
# Cost after step    10: 0.256169
# Cost after step    11: 0.252753
# Cost after step    12: 0.250073
# Cost after step    13: 0.247846
# Cost after step    14: 0.245906
# Cost after step    15: 0.244150
# Cost after step    16: 0.242510
# Cost after step    17: 0.240943
# Cost after step    18: 0.239415
# Cost after step    19: 0.237901
# Cost after step    20: 0.236380
# Cost after step    21: 0.234834
# Cost after step    22: 0.233244
# Cost after step    23: 0.231594
# Cost after step    24: 0.229864
# Cost after step    25: 0.228038
# Cost after step    26: 0.226095
# Cost after step    27: 0.224015
# Cost after step    28: 0.221777
# Cost after step    29: 0.219360
# Cost after step    30: 0.216740
# Cost after step    31: 0.213898
# Cost after step    32: 0.210813
# Cost after step    33: 0.207467
# Cost after step    34: 0.203845
# Cost after step    35: 0.199939
# Cost after step    36: 0.195744
# Cost after step    37: 0.191262
# Cost after step    38: 0.186503
# Cost after step    39: 0.181485
# Cost after step    40: 0.176230
# Cost after step    41: 0.170772
# Cost after step    42: 0.165146
# Cost after step    43: 0.159394
# Cost after step    44: 0.153561
# Cost after step    45: 0.147694
# Cost after step    46: 0.141842
# Cost after step    47: 0.136052
# Cost after step    48: 0.130368
# Cost after step    49: 0.124831
# Cost after step    50: 0.119475
# Cost after step    51: 0.114328
# Cost after step    52: 0.109411
# Cost after step    53: 0.104735
# Cost after step    54: 0.100304
# Cost after step    55: 0.096116
# Cost after step    56: 0.092162
# Cost after step    57: 0.088429
# Cost after step    58: 0.084899
# Cost after step    59: 0.081556
# Cost after step    60: 0.078380
# Cost after step    61: 0.075353
# Cost after step    62: 0.072458
# Cost after step    63: 0.069678
# Cost after step    64: 0.067003
# Cost after step    65: 0.064420
# Cost after step    66: 0.061922
# Cost after step    67: 0.059502
# Cost after step    68: 0.057156
# Cost after step    69: 0.054881
# Cost after step    70: 0.052676
# Cost after step    71: 0.050541
# Cost after step    72: 0.048475
# Cost after step    73: 0.046479
# Cost after step    74: 0.044554
# Cost after step    75: 0.042700
# Cost after step    76: 0.040917
# Cost after step    77: 0.039205
# Cost after step    78: 0.037563
# Cost after step    79: 0.035991
# Cost after step    80: 0.034487
# Cost after step    81: 0.033050
# Cost after step    82: 0.031678
# Cost after step    83: 0.030368
# Cost after step    84: 0.029118
# Cost after step    85: 0.027926
# Cost after step    86: 0.026790
# Cost after step    87: 0.025705
# Cost after step    88: 0.024671
# Cost after step    89: 0.023684
# Cost after step    90: 0.022741
# Cost after step    91: 0.021841
# Cost after step    92: 0.020980
# Cost after step    93: 0.020158
# Cost after step    94: 0.019370
# Cost after step    95: 0.018617
# Cost after step    96: 0.017895
# Cost after step    97: 0.017202
# Cost after step    98: 0.016538
# Cost after step    99: 0.015901
# Cost after step   100: 0.015289
# Cost after step   101: 0.014701
# Cost after step   102: 0.014136
# Cost after step   103: 0.013593
# Cost after step   104: 0.013070
# Cost after step   105: 0.012567
# Cost after step   106: 0.012082
# Cost after step   107: 0.011616
# Cost after step   108: 0.011167
# Cost after step   109: 0.010734
# Cost after step   110: 0.010317
# Cost after step   111: 0.009915
# Cost after step   112: 0.009528
# Cost after step   113: 0.009155
# Cost after step   114: 0.008796
# Cost after step   115: 0.008450
# Cost after step   116: 0.008116
# Cost after step   117: 0.007794
# Cost after step   118: 0.007485
# Cost after step   119: 0.007186
# Cost after step   120: 0.006899
# Cost after step   121: 0.006622
# Cost after step   122: 0.006355
# Cost after step   123: 0.006099
# Cost after step   124: 0.005851
# Cost after step   125: 0.005613
# Cost after step   126: 0.005384
# Cost after step   127: 0.005164
# Cost after step   128: 0.004952
# Cost after step   129: 0.004748
# Cost after step   130: 0.004552
# Cost after step   131: 0.004364
# Cost after step   132: 0.004182
# Cost after step   133: 0.004008
# Cost after step   134: 0.003840
# Cost after step   135: 0.003680
# Cost after step   136: 0.003525
# Cost after step   137: 0.003376
# Cost after step   138: 0.003234
# Cost after step   139: 0.003097
# Cost after step   140: 0.002965
# Cost after step   141: 0.002839
# Cost after step   142: 0.002718
# Cost after step   143: 0.002602
# Cost after step   144: 0.002490
# Cost after step   145: 0.002383
# Cost after step   146: 0.002281
# Cost after step   147: 0.002182
# Cost after step   148: 0.002088
# Cost after step   149: 0.001997
# Cost after step   150: 0.001911
# Cost after step   151: 0.001828
# Cost after step   152: 0.001748
# Cost after step   153: 0.001672
# Cost after step   154: 0.001599
# Cost after step   155: 0.001529
# Cost after step   156: 0.001462
# Cost after step   157: 0.001397
# Cost after step   158: 0.001336
# Cost after step   159: 0.001277
# Cost after step   160: 0.001221
# Cost after step   161: 0.001167
# Cost after step   162: 0.001115
# Cost after step   163: 0.001066
# Cost after step   164: 0.001018
# Cost after step   165: 0.000973
# Cost after step   166: 0.000930
# Cost after step   167: 0.000888
# Cost after step   168: 0.000849
# Cost after step   169: 0.000811
# Cost after step   170: 0.000775
# Cost after step   171: 0.000740
# Cost after step   172: 0.000707
# Cost after step   173: 0.000675
# Cost after step   174: 0.000645
# Cost after step   175: 0.000616
# Cost after step   176: 0.000588
# Cost after step   177: 0.000562
# Cost after step   178: 0.000536
# Cost after step   179: 0.000512
# Cost after step   180: 0.000489
# Cost after step   181: 0.000467
# Cost after step   182: 0.000446
# Cost after step   183: 0.000426
# Cost after step   184: 0.000406
# Cost after step   185: 0.000388
# Cost after step   186: 0.000370
# Cost after step   187: 0.000354
# Cost after step   188: 0.000338
# Cost after step   189: 0.000322
# Cost after step   190: 0.000308
# Cost after step   191: 0.000294
# Cost after step   192: 0.000280
# Cost after step   193: 0.000267
# Cost after step   194: 0.000255
# Cost after step   195: 0.000244
# Cost after step   196: 0.000233
# Cost after step   197: 0.000222
# Cost after step   198: 0.000212
# Cost after step   199: 0.000202
# Cost after step   200: 0.000193
# Cost after step   201: 0.000184
# Cost after step   202: 0.000176
# Cost after step   203: 0.000168
# Cost after step   204: 0.000160
# Cost after step   205: 0.000153
# Cost after step   206: 0.000146
# Cost after step   207: 0.000139
# Cost after step   208: 0.000133
# Cost after step   209: 0.000127
# Cost after step   210: 0.000121
# Cost after step   211: 0.000115
# Cost after step   212: 0.000110
# Cost after step   213: 0.000105
# Cost after step   214: 0.000100
# Cost after step   215: 0.000095
# Cost after step   216: 0.000091
# Cost after step   217: 0.000087
# Cost after step   218: 0.000083
# Cost after step   219: 0.000079
# Cost after step   220: 0.000075
# Cost after step   221: 0.000072
# Cost after step   222: 0.000069
# Cost after step   223: 0.000066
# Cost after step   224: 0.000063
# Cost after step   225: 0.000060
# Cost after step   226: 0.000057
# Cost after step   227: 0.000054
# Cost after step   228: 0.000052
# Cost after step   229: 0.000049
# Cost after step   230: 0.000047
# Cost after step   231: 0.000045
# Cost after step   232: 0.000043
# Cost after step   233: 0.000041
# Cost after step   234: 0.000039
# Cost after step   235: 0.000037
# Cost after step   236: 0.000036
# Cost after step   237: 0.000034
# Cost after step   238: 0.000032
# Cost after step   239: 0.000031
# Cost after step   240: 0.000029
# Cost after step   241: 0.000028
# Cost after step   242: 0.000027
# Cost after step   243: 0.000026
# Cost after step   244: 0.000024
# Cost after step   245: 0.000023
# Cost after step   246: 0.000022
# Cost after step   247: 0.000021
# Cost after step   248: 0.000020
# Cost after step   249: 0.000019
# Cost after step   250: 0.000018
# Cost after step   251: 0.000017
# Cost after step   252: 0.000017
# Cost after step   253: 0.000016
# Cost after step   254: 0.000015
# Cost after step   255: 0.000014
# Cost after step   256: 0.000014
# Cost after step   257: 0.000013
# Cost after step   258: 0.000013
# Cost after step   259: 0.000012
# Cost after step   260: 0.000011
# Cost after step   261: 0.000011
# Cost after step   262: 0.000010
# Cost after step   263: 0.000010
# Cost after step   264: 0.000009
# Cost after step   265: 0.000009
# Cost after step   266: 0.000009
# Cost after step   267: 0.000008
# Cost after step   268: 0.000008
# Cost after step   269: 0.000007
# Cost after step   270: 0.000007
# Cost after step   271: 0.000007
# Cost after step   272: 0.000006
# Cost after step   273: 0.000006
# Cost after step   274: 0.000006
# Cost after step   275: 0.000006
# Cost after step   276: 0.000005
# Cost after step   277: 0.000005
# Cost after step   278: 0.000005
# Cost after step   279: 0.000005
# Cost after step   280: 0.000004
# Cost after step   281: 0.000004
# Cost after step   282: 0.000004
# Cost after step   283: 0.000004
# Cost after step   284: 0.000004
# Cost after step   285: 0.000004
# Cost after step   286: 0.000003
# Cost after step   287: 0.000003
# Cost after step   288: 0.000003
# Cost after step   289: 0.000003
# Cost after step   290: 0.000003
# Cost after step   291: 0.000003
# Cost after step   292: 0.000003
# Cost after step   293: 0.000002
# Cost after step   294: 0.000002
# Cost after step   295: 0.000002
# Cost after step   296: 0.000002
# Cost after step   297: 0.000002
# Cost after step   298: 0.000002
# Cost after step   299: 0.000002
# Cost after step   300: 0.000002
# Cost after step   301: 0.000002
# Cost after step   302: 0.000002
# Cost after step   303: 0.000001
# Cost after step   304: 0.000001
# Cost after step   305: 0.000001
# Cost after step   306: 0.000001
# Cost after step   307: 0.000001
# Cost after step   308: 0.000001
# Cost after step   309: 0.000001
# Cost after step   310: 0.000001
# Cost after step   311: 0.000001
# Cost after step   312: 0.000001
# Cost after step   313: 0.000001
# Cost after step   314: 0.000001
# Cost after step   315: 0.000001
# Cost after step   316: 0.000001
# Cost after step   317: 0.000001
# Cost after step   318: 0.000001
# Cost after step   319: 0.000001
# Cost after step   320: 0.000001
# Cost after step   321: 0.000001
# Cost after step   322: 0.000001
# Cost after step   323: 0.000001
# Cost after step   324: 0.000001
# Cost after step   325: 0.000001
# Cost after step   326: 0.000001
# Cost after step   327: 0.000000
# Cost after step   328: 0.000000
# Cost after step   329: 0.000000
# Cost after step   330: 0.000000
# Cost after step   331: 0.000000
# Cost after step   332: 0.000000
# Cost after step   333: 0.000000
# Cost after step   334: 0.000000
# Cost after step   335: 0.000000
# Cost after step   336: 0.000000
# Cost after step   337: 0.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-157-837027fadf1d> in <module>
#      14     params = opt.step(cost, params)
#      15
# ---> 16     print("Cost after step {:5d}: {:8f}".format(i + 1, cost(params)))
#      17 print(f"Optimized params:{params}")
#
# <ipython-input-136-d2ec73124384> in cost(params)
#      60     C2 = 0
#      61     for inp in inputs:
# ---> 62         res = circuit(params,inp)
#      63         C2 = C2 + res
#      64     return 1-C2/len(inputs)
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\qnode.py in __call__(self, *args, **kwargs)
#     566             gradient_kwargs=self.gradient_kwargs,
#     567             override_shots=override_shots,
# --> 568             **self.execute_kwargs,
#     569         )
#     570
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\interfaces\batch\__init__.py in execute(tapes, device, gradient_fn, interface, mode, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion)
#     319
#     320     if gradient_fn == "backprop" or interface is None:
# --> 321         return cache_execute(batch_execute, cache, return_tuple=False, expand_fn=expand_fn)(tapes)
#     322
#     323     # the default execution function is batch_execute
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\interfaces\batch\__init__.py in wrapper(tapes, **kwargs)
#     166         else:
#     167             # execute all unique tapes that do not exist in the cache
# --> 168             res = fn(execution_tapes.values(), **kwargs)
#     169
#     170         final_res = []
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\interfaces\batch\__init__.py in fn(tapes, **kwargs)
#     118         def fn(tapes, **kwargs):  # pylint: disable=function-redefined
#     119             tapes = [expand_fn(tape) for tape in tapes]
# --> 120             return original_fn(tapes, **kwargs)
#     121
#     122     @wraps(fn)
#
# d:\ProgramData\Anaconda3\lib\contextlib.py in inner(*args, **kwds)
#      72         def inner(*args, **kwds):
#      73             with self._recreate_cm():
# ---> 74                 return func(*args, **kwds)
#      75         return inner
#      76
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\_qubit_device.py in batch_execute(self, circuits)
#     276             self.reset()
#     277
# --> 278             res = self.execute(circuit)
#     279             results.append(res)
#     280
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\_qubit_device.py in execute(self, circuit, **kwargs)
#     192
#     193         # apply all circuit operations
# --> 194         self.apply(circuit.operations, rotations=circuit.diagonalizing_gates, **kwargs)
#     195
#     196         # generate computational basis samples
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\devices\default_qubit.py in apply(self, operations, rotations, **kwargs)
#     214                 self._apply_basis_state(operation.parameters[0], operation.wires)
#     215             else:
# --> 216                 self._state = self._apply_operation(self._state, operation)
#     217
#     218         # store the pre-rotated state
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\devices\default_qubit.py in _apply_operation(self, state, operation)
#     239             return self._apply_ops[operation.base_name](state, axes, inverse=operation.inverse)
#     240
# --> 241         matrix = self._get_unitary_matrix(operation)
#     242
#     243         if operation in diagonal_in_z_basis:
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\devices\default_qubit.py in _get_unitary_matrix(self, unitary)
#     546             return unitary.eigvals
#     547
# --> 548         return unitary.matrix
#     549
#     550     @classmethod
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\operation.py in matrix(self)
#     779     @property
#     780     def matrix(self):
# --> 781         op_matrix = self._matrix(*self.parameters)
#     782
#     783         if self.inverse:
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\ops\qubit\parametric_ops.py in _matrix(cls, *params)
#     125
#     126         return qml.math.diag([c, c]) + qml.math.stack(
# --> 127             [qml.math.stack([0, -s]), qml.math.stack([s, 0])]
#     128         )
#     129
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\math\multi_dispatch.py in stack(values, axis)
#     393     interface = _multi_dispatch(values)
#     394     values = np.coerce(values, like=interface)
# --> 395     return np.stack(values, axis=axis, like=interface)
#     396
#     397
#
# d:\ProgramData\Anaconda3\lib\site-packages\autoray\autoray.py in do(fn, like, *args, **kwargs)
#      82         backend = infer_backend(like)
#      83
# ---> 84     return get_lib_fn(backend, fn)(*args, **kwargs)
#      85
#      86
#
# d:\ProgramData\Anaconda3\lib\site-packages\pennylane\numpy\wrapper.py in _wrapped(*args, **kwargs)
#      73
#      74         # evaluate the original object
# ---> 75         res = obj(*args, **kwargs)
#      76
#      77         if isinstance(res, _np.ndarray):
#
# d:\ProgramData\Anaconda3\lib\site-packages\autograd\numpy\numpy_wrapper.py in stack(arrays, axis)
#      86     # primitives defined in this file
#      87
# ---> 88     arrays = [array(arr) for arr in arrays]
#      89     if not arrays:
#      90         raise ValueError('need at least one array to stack')
#
# d:\ProgramData\Anaconda3\lib\site-packages\autograd\numpy\numpy_wrapper.py in <listcomp>(.0)
#      86     # primitives defined in this file
#      87
# ---> 88     arrays = [array(arr) for arr in arrays]
#      89     if not arrays:
#      90         raise ValueError('need at least one array to stack')
#
# d:\ProgramData\Anaconda3\lib\site-packages\autograd\numpy\numpy_wrapper.py in array(A, *args, **kwargs)
#      58         return array_from_args(args, kwargs, *map(array, A))
#      59     else:
# ---> 60         return _array_from_scalar_or_array(args, kwargs, A)
#      61
#      62 def wrap_if_boxes_inside(raw_array, slow_op_name=None):
#
# d:\ProgramData\Anaconda3\lib\site-packages\autograd\tracer.py in f_wrapped(*args, **kwargs)
#      46             return new_box(ans, trace, node)
#      47         else:
# ---> 48             return f_raw(*args, **kwargs)
#      49     f_wrapped.fun = f_raw
#      50     f_wrapped._is_autograd_primitive = True
#
# d:\ProgramData\Anaconda3\lib\site-packages\autograd\numpy\numpy_wrapper.py in _array_from_scalar_or_array(array_args, array_kwargs, scalar)
#      71 @primitive
#      72 def _array_from_scalar_or_array(array_args, array_kwargs, scalar):
# ---> 73     return _np.array(scalar, *array_args, **array_kwargs)
#      74
#      75 @primitive
#
# KeyboardInterrupt:

# %%
for i in range(1,10):
    print(f"n={i}, A: {int(15*i*(i-1)/2)}, \tB: {3*i*(i-1)+6*i}")
# Out:
# n=1, A: 0, 	B: 6
# n=2, A: 15, 	B: 18
# n=3, A: 45, 	B: 36
# n=4, A: 90, 	B: 60
# n=5, A: 150, 	B: 90
# n=6, A: 225, 	B: 126
# n=7, A: 315, 	B: 168
# n=8, A: 420, 	B: 216
# n=9, A: 540, 	B: 270
